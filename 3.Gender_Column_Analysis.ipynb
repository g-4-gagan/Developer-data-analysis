# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('updatedDatasets/Update2.csv')

# %%
df['Gender'].unique()
# Out:
# array(['Male', nan, 'Female', 'Gender non-conforming', 'Other',
#        'Male; Gender non-conforming', 'Female; Transgender',
#        'Male; Female', 'Male; Other', 'Transgender',
#        'Transgender; Gender non-conforming',
#        'Female; Gender non-conforming',
#        'Male; Female; Transgender; Gender non-conforming; Other',
#        'Male; Female; Transgender', 'Male; Female; Other',
#        'Male; Female; Transgender; Gender non-conforming',
#        'Male; Transgender', 'Female; Transgender; Gender non-conforming',
#        'Gender non-conforming; Other',
#        'Male; Female; Gender non-conforming', 'Female; Other',
#        'Male; Transgender; Gender non-conforming', 'Transgender; Other',
#        'Male; Gender non-conforming; Other',
#        'Female; Gender non-conforming; Other',
#        'Male; Female; Gender non-conforming; Other',
#        'Female; Transgender; Other',
#        'Female; Transgender; Gender non-conforming; Other',
#        'Male; Transgender; Other', 'Male; Female; Transgender; Other'],
#       dtype=object)

# %%
df['Gender'].nunique()
# Out:
# 29

# %% [markdown]
# # Segregation/Cleaning Gender

# %% [markdown]
# Making Following Categories : Male , Female , NaN , Other

# %% [markdown]
# Other contains:Transgender, Gender non-conforming

# %%
def gender_sortner(x):
    if(x == 'Male' or x== 'Female' or pd.isna(x)):
        return x
    else:
        return 'Other'
df["Gender"] = df["Gender"].apply(gender_sortner)

# %%
df['Gender'].unique()
# Out:
# array(['Male', nan, 'Female', 'Other'], dtype=object)

# %%
gender_groupby = df.groupby('Gender')

# %% [markdown]
# # GENDER ANALYSIS (WorldWide)

# %%
plt.figure(figsize=(10,6))
plt.pie(df['Gender'].value_counts(), labels = df['Gender'].value_counts().index,
        startangle=90, wedgeprops={'edgecolor': 'black'}, autopct='%1.f%%', shadow=True)
plt.title("Gender Distribution Around World")
# Out:
# Text(0.5, 1.0, 'Gender Distribution Around World')

# %%
plt.figure(figsize=(8,4))
sns.boxenplot(x='Gender',y='Salary',data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Salary'>

# %%
gender_groupby['Salary'].mean()
# Out:
# Gender
# Female    54346.519630
# Male      57497.391317
# Other     56838.943817
# Name: Salary, dtype: float64

# %% [markdown]
# Analysis[ Worldwide Job Satisfaction ]

# %%
gender_groupby['JobSatisfaction'].mean()
# Out:
# Gender
# Female    6.936620
# Male      7.004372
# Other     6.735751
# Name: JobSatisfaction, dtype: float64

# %%
gender_groupby['JobSatisfaction'].count()
# Out:
# Gender
# Female     2130
# Male      26306
# Other       579
# Name: JobSatisfaction, dtype: int64

# %%
plt.figure(figsize=(15,8))
ax=sns.countplot(data=df,x='JobSatisfaction',hue='Gender')
plt.xticks(rotation=45)
for p in ax.patches:
    ax.annotate(format(p.get_height()),(p.get_x(),p.get_height()+0.6))
plt.title(" WORLD  WIDE  JOB  SATISFACTION ")
# Out:
# Text(0.5, 1.0, ' WORLD  WIDE  JOB  SATISFACTION ')

# %%
plt.figure(figsize=(10,6))
sns.violinplot(data=df,x='Gender',y='JobSatisfaction')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='JobSatisfaction'>

# %% [markdown]
# Analysis[ Worldwide Career Satisfaction ]

# %%
gender_groupby['CareerSatisfaction'].count()
# Out:
# Gender
# Female     2237
# Male      27582
# Other       660
# Name: CareerSatisfaction, dtype: int64

# %%
gender_groupby['CareerSatisfaction'].mean()
# Out:
# Gender
# Female    7.185069
# Male      7.394061
# Other     6.924242
# Name: CareerSatisfaction, dtype: float64

# %%
plt.figure(figsize=(15,8))
ax=sns.countplot(data=df,x='CareerSatisfaction',hue='Gender')
plt.xticks(rotation=45)
for p in ax.patches:
    ax.annotate(format(p.get_height()),(p.get_x(),p.get_height()+0.6))
plt.title("WORLD WIDE CAREER SATISFACTION")
# Out:
# Text(0.5, 1.0, 'WORLD WIDE CAREER SATISFACTION')

# %%
plt.figure(figsize=(10,6))
sns.violinplot(data=df,x='Gender',y='CareerSatisfaction')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='CareerSatisfaction'>

# %% [markdown]
# Analysis[ Worldwide YearsCodedJob ]

# %%
gender_groupby['YearsCodedJob'].count()
# Out:
# Gender
# Female     2154
# Male      26489
# Other       613
# Name: YearsCodedJob, dtype: int64

# %%
plt.figure(figsize=(15,8))
ax=sns.countplot(data=df,x='YearsCodedJob',hue='Gender')
plt.xticks(rotation=45)
for p in ax.patches:
    ax.annotate(format(p.get_height()),(p.get_x(),p.get_height()+0.6))
plt.title("WORLD WIDE YEARS CODED JOB")
# Out:
# Text(0.5, 1.0, 'WORLD WIDE YEARS CODED JOB')

# %% [markdown]
# Analysis[ Worldwide EmploymentStatus ]

# %%
gender_groupby['EmploymentStatus'].count()
# Out:
# Gender
# Female     2600
# Male      31589
# Other       858
# Name: EmploymentStatus, dtype: int64

# %%
plt.figure(figsize=(15,8))
ax=sns.countplot(data=df,x='EmploymentStatus',hue='Gender')
plt.xticks(rotation=85)
for p in ax.patches:
    ax.annotate(format(p.get_height()),(p.get_x(),p.get_height()+0.6))
    plt.title("WORLD WIDE EMPLOYMENT STATUS")

# %% [markdown]
# # Gender Analysis India

# %%
df_india=df[df['Country']=='India']
gender_groupby_India = df_india.groupby('Gender')
gender_groupby_India['Salary'].mean()
# Out:
# Gender
# Female    33297.340313
# Male      33225.401283
# Other     33158.461985
# Name: Salary, dtype: float64

# %%
plt.figure(figsize=(10,6))
plt.pie(df_india['Gender'].value_counts(), labels = df_india['Gender'].value_counts().index,
        startangle=90, wedgeprops={'edgecolor': 'black'}, autopct='%1.f%%', shadow=True)
plt.title("Gender Distribution Around World")
# Out:
# Text(0.5, 1.0, 'Gender Distribution Around World')

# %%
plt.figure(figsize=(8,4))
sns.boxenplot(x='Gender',y='Salary',data=df_india)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Salary'>

# %%
gender_groupby_India['JobSatisfaction'].mean()
# Out:
# Gender
# Female    5.648485
# Male      6.222639
# Other     5.750000
# Name: JobSatisfaction, dtype: float64

# %%
plt.figure(figsize=(15,8))
ax=sns.countplot(data=df_india,x='JobSatisfaction',hue='Gender')
plt.xticks(rotation=45)
for p in ax.patches:
    ax.annotate(format(p.get_height()),(p.get_x(),p.get_height()+0.6))
plt.title("JOB SATISFACTION ( I N D I A ) ")
# Out:
# Text(0.5, 1.0, 'JOB SATISFACTION ( I N D I A ) ')

# %%
gender_groupby_India['CareerSatisfaction'].mean()
# Out:
# Gender
# Female    6.028736
# Male      6.856557
# Other     6.428571
# Name: CareerSatisfaction, dtype: float64

# %%
plt.figure(figsize=(15,8))
ax=sns.countplot(data=df_india,x='CareerSatisfaction',hue='Gender')
plt.xticks(rotation=45)
for p in ax.patches:
    ax.annotate(format(p.get_height()),(p.get_x(),p.get_height()+0.6))
plt.title("CAREER SATISFACTION ( I N D I A ) ")
# Out:
# Text(0.5, 1.0, 'CAREER SATISFACTION ( I N D I A ) ')

# %%
df.to_csv('updatedDatasets/Update3.csv',index=False)
df_india.to_csv('updatedDatasets/UpdatedIndia.csv',index=False)
